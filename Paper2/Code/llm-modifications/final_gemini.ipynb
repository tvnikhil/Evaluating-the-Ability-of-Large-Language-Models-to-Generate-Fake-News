# %%
import pandas as pd
df = pd.read_csv('/Users/akhil/Downloads/final_test.tsv', sep='\t')
df.head()

# %%
import vertexai
from vertexai.generative_models import GenerationConfig, GenerativeModel, Part
import json
import time

# Initialize Vertex AI
PROJECT_ID = "gen-lang-client-0539303742"
LOCATION = "us-south1"  # Change to your region
MODEL_ID = "gemini-1.5-pro-001"  # Replace with the correct model ID for Gemini
OUTPUT_FILE = "modified_data.json"
instr = "I will provide news articles data in JSON format, structured across multiple fields. Your task is to generate a subtly modified version that retains the misleading nature of the original article while employing different wording, structure, or details that could effectively evade detection by various common fake news detection models, including a pre-trained RoBERTa model. The modified text must remain coherent, plausible, and natural. Change the language to be moderately sensational and keep the details of the article vague. Ensure the tone is neutral, modifying the content as if it is coming from a popular and reliable source, while still incorporating phrases like ""buzz"" and its synonyms to enhance the sensational aspect. Additionally, ensure that the comments also make the article more difficult to detect by the pre-trained model. Each article will have the columns: content, comment, and category. Every modified article should not have any of these empty: content, comment and category. Do not change the category of the row. Please provide the modified version as a single, cohesive text for each row. If there are any names of people mentioned in the news, keep them as they are. The response should be in valid json. Do not give any intro or outro, or explanation etc. All the three are strings like regular text, they should not contain weird start and stop characters."

vertexai.init(project=PROJECT_ID, location="us-central1")
model = GenerativeModel(model_name=MODEL_ID, system_instruction=instr)
config = GenerationConfig(temperature=2, max_output_tokens=8192, top_p=0.95, response_mime_type="application/json")

# %%
pip install pyarrow

# %%
pip install json_repair
# Out:
# Collecting json_repair
#   Downloading json_repair-0.30.2-py3-none-any.whl.metadata (11 kB)
# Downloading json_repair-0.30.2-py3-none-any.whl (18 kB)
# Installing collected packages: json_repair
# Successfully installed json_repair-0.30.2
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import json
from json_repair import repair_json  # Ensure this library is installed
import time

# Load the .tsv file
file_path = "/Users/akhil/Downloads/final_test.tsv"  # Replace with your file path
data = pd.read_csv(file_path, sep='\t')

# Ensure required columns are present
if 'clean_title' not in data.columns or '6_way_label' not in data.columns:
    raise ValueError("The input file must contain 'clean_title' and '6_way_label' columns.")

# Configuration
batch_size = 84 # Adjust the batch size as needed
OUTPUT_FILE = "modified_data.json"
FAILED_FILE = "failed_batches.json"

# Lists to hold results and errors
modified_data = []
failed_batches = []

# Batch processing loop
for iter, i in enumerate(range(0, len(data), batch_size)):
    batch_df = data.iloc[i : i + batch_size]  # Extract batch
    print(f"Processing batch {iter + 1}/{(len(data) + batch_size - 1) // batch_size} (Rows {i} to {min(i + batch_size - 1, len(data) - 1)})...")

    # Convert the batch DataFrame to JSON
    batch_json = batch_df.to_json(orient="records")

    # Create prompt for the batch
    prompt = f"""
    Modify the title (clean_title) of the following articles while keeping the 6_way_label unchanged.
    Articles (JSON):
    {batch_json}
    """

    try:
        # Generate content using the model
        response = model.generate_content([prompt], generation_config=config)
        modified_text = response.text

        # Ensure response is not empty
        if not modified_text.strip():
            raise ValueError(f"Empty response for batch {iter + 1}")

        # Parse the modified JSON response
        json_objects = json.loads(modified_text)

        # Process each object to sanitize the output
        sanitized_objects = []
        for original, modified in zip(batch_df.to_dict(orient="records"), json_objects):
            # Ensure `clean_title` is modified but `6_way_label` remains unchanged
            sanitized_object = {
                "clean_title": modified.get("clean_title", original["clean_title"]),
                "6_way_label": original["6_way_label"]  # Preserve the original label
            }
            sanitized_objects.append(sanitized_object)

        modified_data.extend(sanitized_objects)  # Add sanitized objects to the list
        print(f"Batch {iter + 1} processed successfully!")

    except json.JSONDecodeError as e:
        print(f"Error decoding JSON in batch {iter + 1}: {e}")

        # Attempt to repair the JSON if it's malformed
        repaired_text = repair_json(modified_text)
        if repaired_text:
            try:
                json_objects = json.loads(repaired_text)

                # Process repaired JSON for sanitization
                sanitized_objects = []
                for original, modified in zip(batch_df.to_dict(orient="records"), json_objects):
                    sanitized_object = {
                        "clean_title": modified.get("clean_title", original["clean_title"]),
                        "6_way_label": original["6_way_label"]  # Preserve the original label
                    }
                    sanitized_objects.append(sanitized_object)

                modified_data.extend(sanitized_objects)
                print(f"Successfully repaired JSON for batch {iter + 1}.")
            except Exception as validation_error:
                print(f"Validation failed for repaired JSON in batch {iter + 1}: {validation_error}")
                failed_batches.append({"batch": iter + 1, "response": repaired_text, "prompt": prompt})
        else:
            failed_batches.append({"batch": iter + 1, "response": modified_text, "prompt": prompt})
    except Exception as e:
        print(f"Unexpected error in batch {iter + 1}: {e}")
        failed_batches.append({"batch": iter + 1, "response": modified_text if 'modified_text' in locals() else None, "prompt": prompt})
    

    # Save progress periodically
    if iter % 10 == 0:  # Save every 10 batches
        with open(OUTPUT_FILE, "w") as json_file:
            json.dump(modified_data, json_file, indent=4)
        print(f"Intermediate data saved to {OUTPUT_FILE}")

    # time.sleep(0.75)  # Respect API rate limits
2
# Save the final modified data to a JSON file
with open(OUTPUT_FILE, "w") as json_file:
    json.dump(modified_data, json_file, indent=4)
print(f"Modified data saved to {OUTPUT_FILE}")

# Save any failed batches for debugging
if failed_batches:
    with open(FAILED_FILE, "w") as failed_file:
        json.dump(failed_batches, failed_file, indent=4)
    print(f"Failed batches saved to {FAILED_FILE}")
# Out:
# Processing batch 1/427 (Rows 0 to 83)...
# Batch 1 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 2/427 (Rows 84 to 167)...
# Batch 2 processed successfully!
# Processing batch 3/427 (Rows 168 to 251)...
# Batch 3 processed successfully!
# Processing batch 4/427 (Rows 252 to 335)...
# Batch 4 processed successfully!
# Processing batch 5/427 (Rows 336 to 419)...
# Batch 5 processed successfully!
# Processing batch 6/427 (Rows 420 to 503)...
# Batch 6 processed successfully!
# Processing batch 7/427 (Rows 504 to 587)...
# Batch 7 processed successfully!
# Processing batch 8/427 (Rows 588 to 671)...
# Batch 8 processed successfully!
# Processing batch 9/427 (Rows 672 to 755)...
# Batch 9 processed successfully!
# Processing batch 10/427 (Rows 756 to 839)...
# Batch 10 processed successfully!
# Processing batch 11/427 (Rows 840 to 923)...
# Batch 11 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 12/427 (Rows 924 to 1007)...
# Batch 12 processed successfully!
# Processing batch 13/427 (Rows 1008 to 1091)...
# Error decoding JSON in batch 13: Expecting ':' delimiter: line 1 column 4477 (char 4476)
# Successfully repaired JSON for batch 13.
# Processing batch 14/427 (Rows 1092 to 1175)...
# Batch 14 processed successfully!
# Processing batch 15/427 (Rows 1176 to 1259)...
# Batch 15 processed successfully!
# Processing batch 16/427 (Rows 1260 to 1343)...
# Batch 16 processed successfully!
# Processing batch 17/427 (Rows 1344 to 1427)...
# Batch 17 processed successfully!
# Processing batch 18/427 (Rows 1428 to 1511)...
# Batch 18 processed successfully!
# Processing batch 19/427 (Rows 1512 to 1595)...
# Batch 19 processed successfully!
# Processing batch 20/427 (Rows 1596 to 1679)...
# Batch 20 processed successfully!
# Processing batch 21/427 (Rows 1680 to 1763)...
# Batch 21 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 22/427 (Rows 1764 to 1847)...
# Batch 22 processed successfully!
# Processing batch 23/427 (Rows 1848 to 1931)...
# Batch 23 processed successfully!
# Processing batch 24/427 (Rows 1932 to 2015)...
# Batch 24 processed successfully!
# Processing batch 25/427 (Rows 2016 to 2099)...
# Batch 25 processed successfully!
# Processing batch 26/427 (Rows 2100 to 2183)...
# Batch 26 processed successfully!
# Processing batch 27/427 (Rows 2184 to 2267)...
# Batch 27 processed successfully!
# Processing batch 28/427 (Rows 2268 to 2351)...
# Batch 28 processed successfully!
# Processing batch 29/427 (Rows 2352 to 2435)...
# Batch 29 processed successfully!
# Processing batch 30/427 (Rows 2436 to 2519)...
# Batch 30 processed successfully!
# Processing batch 31/427 (Rows 2520 to 2603)...
# Batch 31 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 32/427 (Rows 2604 to 2687)...
# Error decoding JSON in batch 32: Expecting ',' delimiter: line 1 column 7398 (char 7397)
# Successfully repaired JSON for batch 32.
# Processing batch 33/427 (Rows 2688 to 2771)...
# Batch 33 processed successfully!
# Processing batch 34/427 (Rows 2772 to 2855)...
# Batch 34 processed successfully!
# Processing batch 35/427 (Rows 2856 to 2939)...
# Batch 35 processed successfully!
# Processing batch 36/427 (Rows 2940 to 3023)...
# Batch 36 processed successfully!
# Processing batch 37/427 (Rows 3024 to 3107)...
# Batch 37 processed successfully!
# Processing batch 38/427 (Rows 3108 to 3191)...
# Batch 38 processed successfully!
# Processing batch 39/427 (Rows 3192 to 3275)...
# Batch 39 processed successfully!
# Processing batch 40/427 (Rows 3276 to 3359)...
# Batch 40 processed successfully!
# Processing batch 41/427 (Rows 3360 to 3443)...
# Batch 41 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 42/427 (Rows 3444 to 3527)...
# Batch 42 processed successfully!
# Processing batch 43/427 (Rows 3528 to 3611)...
# Batch 43 processed successfully!
# Processing batch 44/427 (Rows 3612 to 3695)...
# Batch 44 processed successfully!
# Processing batch 45/427 (Rows 3696 to 3779)...
# Batch 45 processed successfully!
# Processing batch 46/427 (Rows 3780 to 3863)...
# Batch 46 processed successfully!
# Processing batch 47/427 (Rows 3864 to 3947)...
# Batch 47 processed successfully!
# Processing batch 48/427 (Rows 3948 to 4031)...
# Batch 48 processed successfully!
# Processing batch 49/427 (Rows 4032 to 4115)...
# Batch 49 processed successfully!
# Processing batch 50/427 (Rows 4116 to 4199)...
# Batch 50 processed successfully!
# Processing batch 51/427 (Rows 4200 to 4283)...
# Batch 51 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 52/427 (Rows 4284 to 4367)...
# Error decoding JSON in batch 52: Expecting ',' delimiter: line 1 column 3535 (char 3534)
# Successfully repaired JSON for batch 52.
# Processing batch 53/427 (Rows 4368 to 4451)...
# Batch 53 processed successfully!
# Processing batch 54/427 (Rows 4452 to 4535)...
# Batch 54 processed successfully!
# Processing batch 55/427 (Rows 4536 to 4619)...
# Batch 55 processed successfully!
# Processing batch 56/427 (Rows 4620 to 4703)...
# Batch 56 processed successfully!
# Processing batch 57/427 (Rows 4704 to 4787)...
# Batch 57 processed successfully!
# Processing batch 58/427 (Rows 4788 to 4871)...
# Batch 58 processed successfully!
# Processing batch 59/427 (Rows 4872 to 4955)...
# Batch 59 processed successfully!
# Processing batch 60/427 (Rows 4956 to 5039)...
# Batch 60 processed successfully!
# Processing batch 61/427 (Rows 5040 to 5123)...
# Batch 61 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 62/427 (Rows 5124 to 5207)...
# Batch 62 processed successfully!
# Processing batch 63/427 (Rows 5208 to 5291)...
# Batch 63 processed successfully!
# Processing batch 64/427 (Rows 5292 to 5375)...
# Batch 64 processed successfully!
# Processing batch 65/427 (Rows 5376 to 5459)...
# Batch 65 processed successfully!
# Processing batch 66/427 (Rows 5460 to 5543)...
# Batch 66 processed successfully!
# Processing batch 67/427 (Rows 5544 to 5627)...
# Batch 67 processed successfully!
# Processing batch 68/427 (Rows 5628 to 5711)...
# Batch 68 processed successfully!
# Processing batch 69/427 (Rows 5712 to 5795)...
# Batch 69 processed successfully!
# Processing batch 70/427 (Rows 5796 to 5879)...
# Batch 70 processed successfully!
# Processing batch 71/427 (Rows 5880 to 5963)...
# Batch 71 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 72/427 (Rows 5964 to 6047)...
# Batch 72 processed successfully!
# Processing batch 73/427 (Rows 6048 to 6131)...
# Batch 73 processed successfully!
# Processing batch 74/427 (Rows 6132 to 6215)...
# Batch 74 processed successfully!
# Processing batch 75/427 (Rows 6216 to 6299)...
# Batch 75 processed successfully!
# Processing batch 76/427 (Rows 6300 to 6383)...
# Batch 76 processed successfully!
# Processing batch 77/427 (Rows 6384 to 6467)...
# Batch 77 processed successfully!
# Processing batch 78/427 (Rows 6468 to 6551)...
# Batch 78 processed successfully!
# Processing batch 79/427 (Rows 6552 to 6635)...
# Batch 79 processed successfully!
# Processing batch 80/427 (Rows 6636 to 6719)...
# Batch 80 processed successfully!
# Processing batch 81/427 (Rows 6720 to 6803)...
# Batch 81 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 82/427 (Rows 6804 to 6887)...
# Batch 82 processed successfully!
# Processing batch 83/427 (Rows 6888 to 6971)...
# Batch 83 processed successfully!
# Processing batch 84/427 (Rows 6972 to 7055)...
# Batch 84 processed successfully!
# Processing batch 85/427 (Rows 7056 to 7139)...
# Batch 85 processed successfully!
# Processing batch 86/427 (Rows 7140 to 7223)...
# Batch 86 processed successfully!
# Processing batch 87/427 (Rows 7224 to 7307)...
# Error decoding JSON in batch 87: Expecting ',' delimiter: line 1 column 6048 (char 6047)
# Successfully repaired JSON for batch 87.
# Processing batch 88/427 (Rows 7308 to 7391)...
# Batch 88 processed successfully!
# Processing batch 89/427 (Rows 7392 to 7475)...
# Error decoding JSON in batch 89: Expecting ',' delimiter: line 1 column 2388 (char 2387)
# Successfully repaired JSON for batch 89.
# Processing batch 90/427 (Rows 7476 to 7559)...
# Batch 90 processed successfully!
# Processing batch 91/427 (Rows 7560 to 7643)...
# Batch 91 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 92/427 (Rows 7644 to 7727)...
# Batch 92 processed successfully!
# Processing batch 93/427 (Rows 7728 to 7811)...
# Batch 93 processed successfully!
# Processing batch 94/427 (Rows 7812 to 7895)...
# Batch 94 processed successfully!
# Processing batch 95/427 (Rows 7896 to 7979)...
# Batch 95 processed successfully!
# Processing batch 96/427 (Rows 7980 to 8063)...
# Batch 96 processed successfully!
# Processing batch 97/427 (Rows 8064 to 8147)...
# Batch 97 processed successfully!
# Processing batch 98/427 (Rows 8148 to 8231)...
# Batch 98 processed successfully!
# Processing batch 99/427 (Rows 8232 to 8315)...
# Batch 99 processed successfully!
# Processing batch 100/427 (Rows 8316 to 8399)...
# Batch 100 processed successfully!
# Processing batch 101/427 (Rows 8400 to 8483)...
# Batch 101 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 102/427 (Rows 8484 to 8567)...
# Batch 102 processed successfully!
# Processing batch 103/427 (Rows 8568 to 8651)...
# Batch 103 processed successfully!
# Processing batch 104/427 (Rows 8652 to 8735)...
# Batch 104 processed successfully!
# Processing batch 105/427 (Rows 8736 to 8819)...
# Batch 105 processed successfully!
# Processing batch 106/427 (Rows 8820 to 8903)...
# Batch 106 processed successfully!
# Processing batch 107/427 (Rows 8904 to 8987)...
# Batch 107 processed successfully!
# Processing batch 108/427 (Rows 8988 to 9071)...
# Batch 108 processed successfully!
# Processing batch 109/427 (Rows 9072 to 9155)...
# Batch 109 processed successfully!
# Processing batch 110/427 (Rows 9156 to 9239)...
# Batch 110 processed successfully!
# Processing batch 111/427 (Rows 9240 to 9323)...
# Batch 111 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 112/427 (Rows 9324 to 9407)...
# Batch 112 processed successfully!
# Processing batch 113/427 (Rows 9408 to 9491)...
# Batch 113 processed successfully!
# Processing batch 114/427 (Rows 9492 to 9575)...
# Batch 114 processed successfully!
# Processing batch 115/427 (Rows 9576 to 9659)...
# Batch 115 processed successfully!
# Processing batch 116/427 (Rows 9660 to 9743)...
# Batch 116 processed successfully!
# Processing batch 117/427 (Rows 9744 to 9827)...
# Batch 117 processed successfully!
# Processing batch 118/427 (Rows 9828 to 9911)...
# Unexpected error in batch 118: 'str' object has no attribute 'get'
# Processing batch 119/427 (Rows 9912 to 9995)...
# Batch 119 processed successfully!
# Processing batch 120/427 (Rows 9996 to 10079)...
# Batch 120 processed successfully!
# Processing batch 121/427 (Rows 10080 to 10163)...
# Batch 121 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 122/427 (Rows 10164 to 10247)...
# Batch 122 processed successfully!
# Processing batch 123/427 (Rows 10248 to 10331)...
# Batch 123 processed successfully!
# Processing batch 124/427 (Rows 10332 to 10415)...
# Batch 124 processed successfully!
# Processing batch 125/427 (Rows 10416 to 10499)...
# Batch 125 processed successfully!
# Processing batch 126/427 (Rows 10500 to 10583)...
# Batch 126 processed successfully!
# Processing batch 127/427 (Rows 10584 to 10667)...
# Batch 127 processed successfully!
# Processing batch 128/427 (Rows 10668 to 10751)...
# Batch 128 processed successfully!
# Processing batch 129/427 (Rows 10752 to 10835)...
# Batch 129 processed successfully!
# Processing batch 130/427 (Rows 10836 to 10919)...
# Batch 130 processed successfully!
# Processing batch 131/427 (Rows 10920 to 11003)...
# Batch 131 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 132/427 (Rows 11004 to 11087)...
# Batch 132 processed successfully!
# Processing batch 133/427 (Rows 11088 to 11171)...
# Batch 133 processed successfully!
# Processing batch 134/427 (Rows 11172 to 11255)...
# Error decoding JSON in batch 134: Expecting ':' delimiter: line 1 column 622 (char 621)
# Successfully repaired JSON for batch 134.
# Processing batch 135/427 (Rows 11256 to 11339)...
# Batch 135 processed successfully!
# Processing batch 136/427 (Rows 11340 to 11423)...
# Batch 136 processed successfully!
# Processing batch 137/427 (Rows 11424 to 11507)...
# Batch 137 processed successfully!
# Processing batch 138/427 (Rows 11508 to 11591)...
# Batch 138 processed successfully!
# Processing batch 139/427 (Rows 11592 to 11675)...
# Batch 139 processed successfully!
# Processing batch 140/427 (Rows 11676 to 11759)...
# Batch 140 processed successfully!
# Processing batch 141/427 (Rows 11760 to 11843)...
# Batch 141 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 142/427 (Rows 11844 to 11927)...
# Batch 142 processed successfully!
# Processing batch 143/427 (Rows 11928 to 12011)...
# Batch 143 processed successfully!
# Processing batch 144/427 (Rows 12012 to 12095)...
# Batch 144 processed successfully!
# Processing batch 145/427 (Rows 12096 to 12179)...
# Batch 145 processed successfully!
# Processing batch 146/427 (Rows 12180 to 12263)...
# Batch 146 processed successfully!
# Processing batch 147/427 (Rows 12264 to 12347)...
# Batch 147 processed successfully!
# Processing batch 148/427 (Rows 12348 to 12431)...
# Batch 148 processed successfully!
# Processing batch 149/427 (Rows 12432 to 12515)...
# Batch 149 processed successfully!
# Processing batch 150/427 (Rows 12516 to 12599)...
# Batch 150 processed successfully!
# Processing batch 151/427 (Rows 12600 to 12683)...
# Batch 151 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 152/427 (Rows 12684 to 12767)...
# Batch 152 processed successfully!
# Processing batch 153/427 (Rows 12768 to 12851)...
# Batch 153 processed successfully!
# Processing batch 154/427 (Rows 12852 to 12935)...
# Batch 154 processed successfully!
# Processing batch 155/427 (Rows 12936 to 13019)...
# Batch 155 processed successfully!
# Processing batch 156/427 (Rows 13020 to 13103)...
# Batch 156 processed successfully!
# Processing batch 157/427 (Rows 13104 to 13187)...
# Batch 157 processed successfully!
# Processing batch 158/427 (Rows 13188 to 13271)...
# Batch 158 processed successfully!
# Processing batch 159/427 (Rows 13272 to 13355)...
# Batch 159 processed successfully!
# Processing batch 160/427 (Rows 13356 to 13439)...
# Batch 160 processed successfully!
# Processing batch 161/427 (Rows 13440 to 13523)...
# Batch 161 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 162/427 (Rows 13524 to 13607)...
# Batch 162 processed successfully!
# Processing batch 163/427 (Rows 13608 to 13691)...
# Batch 163 processed successfully!
# Processing batch 164/427 (Rows 13692 to 13775)...
# Batch 164 processed successfully!
# Processing batch 165/427 (Rows 13776 to 13859)...
# Batch 165 processed successfully!
# Processing batch 166/427 (Rows 13860 to 13943)...
# Batch 166 processed successfully!
# Processing batch 167/427 (Rows 13944 to 14027)...
# Batch 167 processed successfully!
# Processing batch 168/427 (Rows 14028 to 14111)...
# Batch 168 processed successfully!
# Processing batch 169/427 (Rows 14112 to 14195)...
# Batch 169 processed successfully!
# Processing batch 170/427 (Rows 14196 to 14279)...
# Batch 170 processed successfully!
# Processing batch 171/427 (Rows 14280 to 14363)...
# Batch 171 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 172/427 (Rows 14364 to 14447)...
# Batch 172 processed successfully!
# Processing batch 173/427 (Rows 14448 to 14531)...
# Batch 173 processed successfully!
# Processing batch 174/427 (Rows 14532 to 14615)...
# Batch 174 processed successfully!
# Processing batch 175/427 (Rows 14616 to 14699)...
# Batch 175 processed successfully!
# Processing batch 176/427 (Rows 14700 to 14783)...
# Batch 176 processed successfully!
# Processing batch 177/427 (Rows 14784 to 14867)...
# Batch 177 processed successfully!
# Processing batch 178/427 (Rows 14868 to 14951)...
# Batch 178 processed successfully!
# Processing batch 179/427 (Rows 14952 to 15035)...
# Batch 179 processed successfully!
# Processing batch 180/427 (Rows 15036 to 15119)...
# Batch 180 processed successfully!
# Processing batch 181/427 (Rows 15120 to 15203)...
# Batch 181 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 182/427 (Rows 15204 to 15287)...
# Batch 182 processed successfully!
# Processing batch 183/427 (Rows 15288 to 15371)...
# Batch 183 processed successfully!
# Processing batch 184/427 (Rows 15372 to 15455)...
# Batch 184 processed successfully!
# Processing batch 185/427 (Rows 15456 to 15539)...
# Batch 185 processed successfully!
# Processing batch 186/427 (Rows 15540 to 15623)...
# Batch 186 processed successfully!
# Processing batch 187/427 (Rows 15624 to 15707)...
# Batch 187 processed successfully!
# Processing batch 188/427 (Rows 15708 to 15791)...
# Batch 188 processed successfully!
# Processing batch 189/427 (Rows 15792 to 15875)...
# Batch 189 processed successfully!
# Processing batch 190/427 (Rows 15876 to 15959)...
# Batch 190 processed successfully!
# Processing batch 191/427 (Rows 15960 to 16043)...
# Batch 191 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 192/427 (Rows 16044 to 16127)...
# Batch 192 processed successfully!
# Processing batch 193/427 (Rows 16128 to 16211)...
# Batch 193 processed successfully!
# Processing batch 194/427 (Rows 16212 to 16295)...
# Batch 194 processed successfully!
# Processing batch 195/427 (Rows 16296 to 16379)...
# Batch 195 processed successfully!
# Processing batch 196/427 (Rows 16380 to 16463)...
# Batch 196 processed successfully!
# Processing batch 197/427 (Rows 16464 to 16547)...
# Batch 197 processed successfully!
# Processing batch 198/427 (Rows 16548 to 16631)...
# Batch 198 processed successfully!
# Processing batch 199/427 (Rows 16632 to 16715)...
# Batch 199 processed successfully!
# Processing batch 200/427 (Rows 16716 to 16799)...
# Batch 200 processed successfully!
# Processing batch 201/427 (Rows 16800 to 16883)...
# Batch 201 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 202/427 (Rows 16884 to 16967)...
# Batch 202 processed successfully!
# Processing batch 203/427 (Rows 16968 to 17051)...
# Batch 203 processed successfully!
# Processing batch 204/427 (Rows 17052 to 17135)...
# Batch 204 processed successfully!
# Processing batch 205/427 (Rows 17136 to 17219)...
# Batch 205 processed successfully!
# Processing batch 206/427 (Rows 17220 to 17303)...
# Batch 206 processed successfully!
# Processing batch 207/427 (Rows 17304 to 17387)...
# Batch 207 processed successfully!
# Processing batch 208/427 (Rows 17388 to 17471)...
# Batch 208 processed successfully!
# Processing batch 209/427 (Rows 17472 to 17555)...
# Batch 209 processed successfully!
# Processing batch 210/427 (Rows 17556 to 17639)...
# Batch 210 processed successfully!
# Processing batch 211/427 (Rows 17640 to 17723)...
# Batch 211 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 212/427 (Rows 17724 to 17807)...
# Unexpected error in batch 212: 'str' object has no attribute 'get'
# Processing batch 213/427 (Rows 17808 to 17891)...
# Batch 213 processed successfully!
# Processing batch 214/427 (Rows 17892 to 17975)...
# Batch 214 processed successfully!
# Processing batch 215/427 (Rows 17976 to 18059)...
# Batch 215 processed successfully!
# Processing batch 216/427 (Rows 18060 to 18143)...
# Batch 216 processed successfully!
# Processing batch 217/427 (Rows 18144 to 18227)...
# Batch 217 processed successfully!
# Processing batch 218/427 (Rows 18228 to 18311)...
# Batch 218 processed successfully!
# Processing batch 219/427 (Rows 18312 to 18395)...
# Batch 219 processed successfully!
# Processing batch 220/427 (Rows 18396 to 18479)...
# Batch 220 processed successfully!
# Processing batch 221/427 (Rows 18480 to 18563)...
# Batch 221 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 222/427 (Rows 18564 to 18647)...
# Batch 222 processed successfully!
# Processing batch 223/427 (Rows 18648 to 18731)...
# Batch 223 processed successfully!
# Processing batch 224/427 (Rows 18732 to 18815)...
# Batch 224 processed successfully!
# Processing batch 225/427 (Rows 18816 to 18899)...
# Batch 225 processed successfully!
# Processing batch 226/427 (Rows 18900 to 18983)...
# Batch 226 processed successfully!
# Processing batch 227/427 (Rows 18984 to 19067)...
# Batch 227 processed successfully!
# Processing batch 228/427 (Rows 19068 to 19151)...
# Batch 228 processed successfully!
# Processing batch 229/427 (Rows 19152 to 19235)...
# Batch 229 processed successfully!
# Processing batch 230/427 (Rows 19236 to 19319)...
# Batch 230 processed successfully!
# Processing batch 231/427 (Rows 19320 to 19403)...
# Batch 231 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 232/427 (Rows 19404 to 19487)...
# Error decoding JSON in batch 232: Expecting ',' delimiter: line 1 column 3792 (char 3791)
# Successfully repaired JSON for batch 232.
# Processing batch 233/427 (Rows 19488 to 19571)...
# Batch 233 processed successfully!
# Processing batch 234/427 (Rows 19572 to 19655)...
# Batch 234 processed successfully!
# Processing batch 235/427 (Rows 19656 to 19739)...
# Batch 235 processed successfully!
# Processing batch 236/427 (Rows 19740 to 19823)...
# Batch 236 processed successfully!
# Processing batch 237/427 (Rows 19824 to 19907)...
# Batch 237 processed successfully!
# Processing batch 238/427 (Rows 19908 to 19991)...
# Batch 238 processed successfully!
# Processing batch 239/427 (Rows 19992 to 20075)...
# Error decoding JSON in batch 239: Expecting ',' delimiter: line 1 column 4251 (char 4250)
# Successfully repaired JSON for batch 239.
# Processing batch 240/427 (Rows 20076 to 20159)...
# Batch 240 processed successfully!
# Processing batch 241/427 (Rows 20160 to 20243)...
# Batch 241 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 242/427 (Rows 20244 to 20327)...
# Batch 242 processed successfully!
# Processing batch 243/427 (Rows 20328 to 20411)...
# Batch 243 processed successfully!
# Processing batch 244/427 (Rows 20412 to 20495)...
# Batch 244 processed successfully!
# Processing batch 245/427 (Rows 20496 to 20579)...
# Batch 245 processed successfully!
# Processing batch 246/427 (Rows 20580 to 20663)...
# Batch 246 processed successfully!
# Processing batch 247/427 (Rows 20664 to 20747)...
# Batch 247 processed successfully!
# Processing batch 248/427 (Rows 20748 to 20831)...
# Batch 248 processed successfully!
# Processing batch 249/427 (Rows 20832 to 20915)...
# Batch 249 processed successfully!
# Processing batch 250/427 (Rows 20916 to 20999)...
# Batch 250 processed successfully!
# Processing batch 251/427 (Rows 21000 to 21083)...
# Batch 251 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 252/427 (Rows 21084 to 21167)...
# Batch 252 processed successfully!
# Processing batch 253/427 (Rows 21168 to 21251)...
# Batch 253 processed successfully!
# Processing batch 254/427 (Rows 21252 to 21335)...
# Batch 254 processed successfully!
# Processing batch 255/427 (Rows 21336 to 21419)...
# Batch 255 processed successfully!
# Processing batch 256/427 (Rows 21420 to 21503)...
# Batch 256 processed successfully!
# Processing batch 257/427 (Rows 21504 to 21587)...
# Batch 257 processed successfully!
# Processing batch 258/427 (Rows 21588 to 21671)...
# Batch 258 processed successfully!
# Processing batch 259/427 (Rows 21672 to 21755)...
# Batch 259 processed successfully!
# Processing batch 260/427 (Rows 21756 to 21839)...
# Batch 260 processed successfully!
# Processing batch 261/427 (Rows 21840 to 21923)...
# Batch 261 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 262/427 (Rows 21924 to 22007)...
# Batch 262 processed successfully!
# Processing batch 263/427 (Rows 22008 to 22091)...
# Batch 263 processed successfully!
# Processing batch 264/427 (Rows 22092 to 22175)...
# Batch 264 processed successfully!
# Processing batch 265/427 (Rows 22176 to 22259)...
# Batch 265 processed successfully!
# Processing batch 266/427 (Rows 22260 to 22343)...
# Batch 266 processed successfully!
# Processing batch 267/427 (Rows 22344 to 22427)...
# Batch 267 processed successfully!
# Processing batch 268/427 (Rows 22428 to 22511)...
# Batch 268 processed successfully!
# Processing batch 269/427 (Rows 22512 to 22595)...
# Batch 269 processed successfully!
# Processing batch 270/427 (Rows 22596 to 22679)...
# Batch 270 processed successfully!
# Processing batch 271/427 (Rows 22680 to 22763)...
# Batch 271 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 272/427 (Rows 22764 to 22847)...
# Batch 272 processed successfully!
# Processing batch 273/427 (Rows 22848 to 22931)...
# Batch 273 processed successfully!
# Processing batch 274/427 (Rows 22932 to 23015)...
# Batch 274 processed successfully!
# Processing batch 275/427 (Rows 23016 to 23099)...
# Batch 275 processed successfully!
# Processing batch 276/427 (Rows 23100 to 23183)...
# Batch 276 processed successfully!
# Processing batch 277/427 (Rows 23184 to 23267)...
# Batch 277 processed successfully!
# Processing batch 278/427 (Rows 23268 to 23351)...
# Batch 278 processed successfully!
# Processing batch 279/427 (Rows 23352 to 23435)...
# Batch 279 processed successfully!
# Processing batch 280/427 (Rows 23436 to 23519)...
# Batch 280 processed successfully!
# Processing batch 281/427 (Rows 23520 to 23603)...
# Batch 281 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 282/427 (Rows 23604 to 23687)...
# Batch 282 processed successfully!
# Processing batch 283/427 (Rows 23688 to 23771)...
# Batch 283 processed successfully!
# Processing batch 284/427 (Rows 23772 to 23855)...
# Batch 284 processed successfully!
# Processing batch 285/427 (Rows 23856 to 23939)...
# Batch 285 processed successfully!
# Processing batch 286/427 (Rows 23940 to 24023)...
# Batch 286 processed successfully!
# Processing batch 287/427 (Rows 24024 to 24107)...
# Batch 287 processed successfully!
# Processing batch 288/427 (Rows 24108 to 24191)...
# Batch 288 processed successfully!
# Processing batch 289/427 (Rows 24192 to 24275)...
# Batch 289 processed successfully!
# Processing batch 290/427 (Rows 24276 to 24359)...
# Batch 290 processed successfully!
# Processing batch 291/427 (Rows 24360 to 24443)...
# Batch 291 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 292/427 (Rows 24444 to 24527)...
# Batch 292 processed successfully!
# Processing batch 293/427 (Rows 24528 to 24611)...
# Batch 293 processed successfully!
# Processing batch 294/427 (Rows 24612 to 24695)...
# Batch 294 processed successfully!
# Processing batch 295/427 (Rows 24696 to 24779)...
# Batch 295 processed successfully!
# Processing batch 296/427 (Rows 24780 to 24863)...
# Batch 296 processed successfully!
# Processing batch 297/427 (Rows 24864 to 24947)...
# Batch 297 processed successfully!
# Processing batch 298/427 (Rows 24948 to 25031)...
# Batch 298 processed successfully!
# Processing batch 299/427 (Rows 25032 to 25115)...
# Batch 299 processed successfully!
# Processing batch 300/427 (Rows 25116 to 25199)...
# Batch 300 processed successfully!
# Processing batch 301/427 (Rows 25200 to 25283)...
# Batch 301 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 302/427 (Rows 25284 to 25367)...
# Batch 302 processed successfully!
# Processing batch 303/427 (Rows 25368 to 25451)...
# Batch 303 processed successfully!
# Processing batch 304/427 (Rows 25452 to 25535)...
# Batch 304 processed successfully!
# Processing batch 305/427 (Rows 25536 to 25619)...
# Batch 305 processed successfully!
# Processing batch 306/427 (Rows 25620 to 25703)...
# Batch 306 processed successfully!
# Processing batch 307/427 (Rows 25704 to 25787)...
# Batch 307 processed successfully!
# Processing batch 308/427 (Rows 25788 to 25871)...
# Batch 308 processed successfully!
# Processing batch 309/427 (Rows 25872 to 25955)...
# Batch 309 processed successfully!
# Processing batch 310/427 (Rows 25956 to 26039)...
# Batch 310 processed successfully!
# Processing batch 311/427 (Rows 26040 to 26123)...
# Batch 311 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 312/427 (Rows 26124 to 26207)...
# Batch 312 processed successfully!
# Processing batch 313/427 (Rows 26208 to 26291)...
# Batch 313 processed successfully!
# Processing batch 314/427 (Rows 26292 to 26375)...
# Batch 314 processed successfully!
# Processing batch 315/427 (Rows 26376 to 26459)...
# Batch 315 processed successfully!
# Processing batch 316/427 (Rows 26460 to 26543)...
# Unexpected error in batch 316: 'str' object has no attribute 'get'
# Processing batch 317/427 (Rows 26544 to 26627)...
# Batch 317 processed successfully!
# Processing batch 318/427 (Rows 26628 to 26711)...
# Batch 318 processed successfully!
# Processing batch 319/427 (Rows 26712 to 26795)...
# Batch 319 processed successfully!
# Processing batch 320/427 (Rows 26796 to 26879)...
# Batch 320 processed successfully!
# Processing batch 321/427 (Rows 26880 to 26963)...
# Batch 321 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 322/427 (Rows 26964 to 27047)...
# Batch 322 processed successfully!
# Processing batch 323/427 (Rows 27048 to 27131)...
# Batch 323 processed successfully!
# Processing batch 324/427 (Rows 27132 to 27215)...
# Batch 324 processed successfully!
# Processing batch 325/427 (Rows 27216 to 27299)...
# Batch 325 processed successfully!
# Processing batch 326/427 (Rows 27300 to 27383)...
# Error decoding JSON in batch 326: Expecting ',' delimiter: line 1 column 7735 (char 7734)
# Successfully repaired JSON for batch 326.
# Processing batch 327/427 (Rows 27384 to 27467)...
# Batch 327 processed successfully!
# Processing batch 328/427 (Rows 27468 to 27551)...
# Batch 328 processed successfully!
# Processing batch 329/427 (Rows 27552 to 27635)...
# Batch 329 processed successfully!
# Processing batch 330/427 (Rows 27636 to 27719)...
# Batch 330 processed successfully!
# Processing batch 331/427 (Rows 27720 to 27803)...
# Batch 331 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 332/427 (Rows 27804 to 27887)...
# Batch 332 processed successfully!
# Processing batch 333/427 (Rows 27888 to 27971)...
# Batch 333 processed successfully!
# Processing batch 334/427 (Rows 27972 to 28055)...
# Batch 334 processed successfully!
# Processing batch 335/427 (Rows 28056 to 28139)...
# Batch 335 processed successfully!
# Processing batch 336/427 (Rows 28140 to 28223)...
# Batch 336 processed successfully!
# Processing batch 337/427 (Rows 28224 to 28307)...
# Batch 337 processed successfully!
# Processing batch 338/427 (Rows 28308 to 28391)...
# Batch 338 processed successfully!
# Processing batch 339/427 (Rows 28392 to 28475)...
# Batch 339 processed successfully!
# Processing batch 340/427 (Rows 28476 to 28559)...
# Batch 340 processed successfully!
# Processing batch 341/427 (Rows 28560 to 28643)...
# Batch 341 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 342/427 (Rows 28644 to 28727)...
# Batch 342 processed successfully!
# Processing batch 343/427 (Rows 28728 to 28811)...
# Batch 343 processed successfully!
# Processing batch 344/427 (Rows 28812 to 28895)...
# Batch 344 processed successfully!
# Processing batch 345/427 (Rows 28896 to 28979)...
# Batch 345 processed successfully!
# Processing batch 346/427 (Rows 28980 to 29063)...
# Batch 346 processed successfully!
# Processing batch 347/427 (Rows 29064 to 29147)...
# Batch 347 processed successfully!
# Processing batch 348/427 (Rows 29148 to 29231)...
# Batch 348 processed successfully!
# Processing batch 349/427 (Rows 29232 to 29315)...
# Batch 349 processed successfully!
# Processing batch 350/427 (Rows 29316 to 29399)...
# Batch 350 processed successfully!
# Processing batch 351/427 (Rows 29400 to 29483)...
# Batch 351 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 352/427 (Rows 29484 to 29567)...
# Batch 352 processed successfully!
# Processing batch 353/427 (Rows 29568 to 29651)...
# Batch 353 processed successfully!
# Processing batch 354/427 (Rows 29652 to 29735)...
# Batch 354 processed successfully!
# Processing batch 355/427 (Rows 29736 to 29819)...
# Batch 355 processed successfully!
# Processing batch 356/427 (Rows 29820 to 29903)...
# Batch 356 processed successfully!
# Processing batch 357/427 (Rows 29904 to 29987)...
# Batch 357 processed successfully!
# Processing batch 358/427 (Rows 29988 to 30071)...
# Batch 358 processed successfully!
# Processing batch 359/427 (Rows 30072 to 30155)...
# Batch 359 processed successfully!
# Processing batch 360/427 (Rows 30156 to 30239)...
# Batch 360 processed successfully!
# Processing batch 361/427 (Rows 30240 to 30323)...
# Batch 361 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 362/427 (Rows 30324 to 30407)...
# Batch 362 processed successfully!
# Processing batch 363/427 (Rows 30408 to 30491)...
# Batch 363 processed successfully!
# Processing batch 364/427 (Rows 30492 to 30575)...
# Batch 364 processed successfully!
# Processing batch 365/427 (Rows 30576 to 30659)...
# Batch 365 processed successfully!
# Processing batch 366/427 (Rows 30660 to 30743)...
# Batch 366 processed successfully!
# Processing batch 367/427 (Rows 30744 to 30827)...
# Batch 367 processed successfully!
# Processing batch 368/427 (Rows 30828 to 30911)...
# Batch 368 processed successfully!
# Processing batch 369/427 (Rows 30912 to 30995)...
# Batch 369 processed successfully!
# Processing batch 370/427 (Rows 30996 to 31079)...
# Batch 370 processed successfully!
# Processing batch 371/427 (Rows 31080 to 31163)...
# Batch 371 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 372/427 (Rows 31164 to 31247)...
# Batch 372 processed successfully!
# Processing batch 373/427 (Rows 31248 to 31331)...
# Batch 373 processed successfully!
# Processing batch 374/427 (Rows 31332 to 31415)...
# Batch 374 processed successfully!
# Processing batch 375/427 (Rows 31416 to 31499)...
# Batch 375 processed successfully!
# Processing batch 376/427 (Rows 31500 to 31583)...
# Batch 376 processed successfully!
# Processing batch 377/427 (Rows 31584 to 31667)...
# Batch 377 processed successfully!
# Processing batch 378/427 (Rows 31668 to 31751)...
# Error decoding JSON in batch 378: Expecting ',' delimiter: line 1 column 4137 (char 4136)
# Successfully repaired JSON for batch 378.
# Processing batch 379/427 (Rows 31752 to 31835)...
# Batch 379 processed successfully!
# Processing batch 380/427 (Rows 31836 to 31919)...
# Batch 380 processed successfully!
# Processing batch 381/427 (Rows 31920 to 32003)...
# Batch 381 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 382/427 (Rows 32004 to 32087)...
# Batch 382 processed successfully!
# Processing batch 383/427 (Rows 32088 to 32171)...
# Batch 383 processed successfully!
# Processing batch 384/427 (Rows 32172 to 32255)...
# Batch 384 processed successfully!
# Processing batch 385/427 (Rows 32256 to 32339)...
# Batch 385 processed successfully!
# Processing batch 386/427 (Rows 32340 to 32423)...
# Batch 386 processed successfully!
# Processing batch 387/427 (Rows 32424 to 32507)...
# Batch 387 processed successfully!
# Processing batch 388/427 (Rows 32508 to 32591)...
# Batch 388 processed successfully!
# Processing batch 389/427 (Rows 32592 to 32675)...
# Batch 389 processed successfully!
# Processing batch 390/427 (Rows 32676 to 32759)...
# Batch 390 processed successfully!
# Processing batch 391/427 (Rows 32760 to 32843)...
# Batch 391 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 392/427 (Rows 32844 to 32927)...
# Batch 392 processed successfully!
# Processing batch 393/427 (Rows 32928 to 33011)...
# Batch 393 processed successfully!
# Processing batch 394/427 (Rows 33012 to 33095)...
# Batch 394 processed successfully!
# Processing batch 395/427 (Rows 33096 to 33179)...
# Batch 395 processed successfully!
# Processing batch 396/427 (Rows 33180 to 33263)...
# Batch 396 processed successfully!
# Processing batch 397/427 (Rows 33264 to 33347)...
# Batch 397 processed successfully!
# Processing batch 398/427 (Rows 33348 to 33431)...
# Batch 398 processed successfully!
# Processing batch 399/427 (Rows 33432 to 33515)...
# Batch 399 processed successfully!
# Processing batch 400/427 (Rows 33516 to 33599)...
# Batch 400 processed successfully!
# Processing batch 401/427 (Rows 33600 to 33683)...
# Batch 401 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 402/427 (Rows 33684 to 33767)...
# Batch 402 processed successfully!
# Processing batch 403/427 (Rows 33768 to 33851)...
# Batch 403 processed successfully!
# Processing batch 404/427 (Rows 33852 to 33935)...
# Batch 404 processed successfully!
# Processing batch 405/427 (Rows 33936 to 34019)...
# Batch 405 processed successfully!
# Processing batch 406/427 (Rows 34020 to 34103)...
# Batch 406 processed successfully!
# Processing batch 407/427 (Rows 34104 to 34187)...
# Batch 407 processed successfully!
# Processing batch 408/427 (Rows 34188 to 34271)...
# Batch 408 processed successfully!
# Processing batch 409/427 (Rows 34272 to 34355)...
# Batch 409 processed successfully!
# Processing batch 410/427 (Rows 34356 to 34439)...
# Batch 410 processed successfully!
# Processing batch 411/427 (Rows 34440 to 34523)...
# Batch 411 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 412/427 (Rows 34524 to 34607)...
# Batch 412 processed successfully!
# Processing batch 413/427 (Rows 34608 to 34691)...
# Batch 413 processed successfully!
# Processing batch 414/427 (Rows 34692 to 34775)...
# Batch 414 processed successfully!
# Processing batch 415/427 (Rows 34776 to 34859)...
# Batch 415 processed successfully!
# Processing batch 416/427 (Rows 34860 to 34943)...
# Batch 416 processed successfully!
# Processing batch 417/427 (Rows 34944 to 35027)...
# Batch 417 processed successfully!
# Processing batch 418/427 (Rows 35028 to 35111)...
# Batch 418 processed successfully!
# Processing batch 419/427 (Rows 35112 to 35195)...
# Batch 419 processed successfully!
# Processing batch 420/427 (Rows 35196 to 35279)...
# Batch 420 processed successfully!
# Processing batch 421/427 (Rows 35280 to 35363)...
# Batch 421 processed successfully!
# Intermediate data saved to modified_data.json
# Processing batch 422/427 (Rows 35364 to 35447)...
# Batch 422 processed successfully!
# Processing batch 423/427 (Rows 35448 to 35531)...
# Batch 423 processed successfully!
# Processing batch 424/427 (Rows 35532 to 35615)...
# Batch 424 processed successfully!
# Processing batch 425/427 (Rows 35616 to 35699)...
# Batch 425 processed successfully!
# Processing batch 426/427 (Rows 35700 to 35783)...
# Batch 426 processed successfully!
# Processing batch 427/427 (Rows 35784 to 35811)...
# Batch 427 processed successfully!
# Modified data saved to modified_data.json
# Failed batches saved to failed_batches.json
